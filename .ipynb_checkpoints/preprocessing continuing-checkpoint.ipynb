# %% [markdown]
# <font size="6">Pre-Processing and Training Data Development</font>

# %% [markdown]
# Import tools and load the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_curve, auc,ConfusionMatrixDisplay

# %%
df=pd.read_csv('..\Capstone-2-Data-wranglling\healthcare-dataset-stroke-data.csv',index_col='id')

# %%
df=df[df['gender']!='Other']
df[df['gender']=='Other']
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# bmi columns missing values are replaced with median of its own.

# %%
df['bmi']=df['bmi'].fillna(df['bmi'].median())

# %%
df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.6  formerly smoked       1
# 51676          Rural             202.21  28.1     never smoked       1
# 31112          Rural             105.92  32.5     never smoked       1
# 60182          Urban             171.23  34.4           smokes       1
# 1665           Rural             174.12  24.0     never smoked       1

# %% [markdown]
# Select all the columns except for stroke and seperate them into two variables.

# %%
features=['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status']

# %%
X=df[features]
y=df.stroke

# %%
X
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
#       Residence_type  avg_glucose_level   bmi   smoking_status
# id
# 9046           Urban             228.69  36.6  formerly smoked
# 51676          Rural             202.21  28.1     never smoked
# 31112          Rural             105.92  32.5     never smoked
# 60182          Urban             171.23  34.4           smokes
# 1665           Rural             174.12  24.0     never smoked
# ...              ...                ...   ...              ...
# 18234          Urban              83.75  28.1     never smoked
# 44873          Urban             125.20  40.0     never smoked
# 19723          Rural              82.99  30.6     never smoked
# 37544          Rural             166.29  25.6  formerly smoked
# 44679          Urban              85.28  26.2          Unknown
#
# [5109 rows x 10 columns]

# %%
y
# Out:
# id
# 9046     1
# 51676    1
# 31112    1
# 60182    1
# 1665     1
#         ..
# 18234    0
# 44873    0
# 19723    0
# 37544    0
# 44679    0
# Name: stroke, Length: 5109, dtype: int64

# %% [markdown]
# Numeric and Categorical data was seperated before the stnadard scale was applied by using the number of unique values in each column.

# %%
numeric_data=df.loc[:,df.nunique()>5]
a=numeric_data.columns
b=a.to_list()
categorical_data=df.drop(columns=(b),axis=1)
categorical_data.drop('stroke',axis=1,inplace=True)
categorical_data
# Out:
#        gender  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male             0              1          Yes        Private
# 51676  Female             0              0          Yes  Self-employed
# 31112    Male             0              1          Yes        Private
# 60182  Female             0              0          Yes        Private
# 1665   Female             1              0          Yes  Self-employed
# ...       ...           ...            ...          ...            ...
# 18234  Female             1              0          Yes        Private
# 44873  Female             0              0          Yes  Self-employed
# 19723  Female             0              0          Yes  Self-employed
# 37544    Male             0              0          Yes        Private
# 44679  Female             0              0          Yes       Govt_job
#
#       Residence_type   smoking_status
# id
# 9046           Urban  formerly smoked
# 51676          Rural     never smoked
# 31112          Rural     never smoked
# 60182          Urban           smokes
# 1665           Rural     never smoked
# ...              ...              ...
# 18234          Urban     never smoked
# 44873          Urban     never smoked
# 19723          Rural     never smoked
# 37544          Rural  formerly smoked
# 44679          Urban          Unknown
#
# [5109 rows x 7 columns]

# %%
df[b]
# Out:
#         age  avg_glucose_level   bmi
# id
# 9046   67.0             228.69  36.6
# 51676  61.0             202.21  28.1
# 31112  80.0             105.92  32.5
# 60182  49.0             171.23  34.4
# 1665   79.0             174.12  24.0
# ...     ...                ...   ...
# 18234  80.0              83.75  28.1
# 44873  81.0             125.20  40.0
# 19723  35.0              82.99  30.6
# 37544  51.0             166.29  25.6
# 44679  44.0              85.28  26.2
#
# [5109 rows x 3 columns]

# %% [markdown]
# StamdardScaler was applied to numerical columns

# %%
stdscaler=StandardScaler()
df[b]=stdscaler.fit_transform(df[b])

# %%
df[b]
# Out:
#             age  avg_glucose_level       bmi
# id
# 9046   1.051242           2.706450  1.004893
# 51676  0.785889           2.121652 -0.099142
# 31112  1.626174          -0.004867  0.472358
# 60182  0.255182           1.437473  0.719142
# 1665   1.581949           1.501297 -0.631677
# ...         ...                ...       ...
# 18234  1.626174          -0.494481 -0.099142
# 44873  1.670400           0.420922  1.446507
# 19723 -0.363976          -0.511266  0.225574
# 37544  0.343633           1.328375 -0.423859
# 44679  0.034054          -0.460692 -0.345927
#
# [5109 rows x 3 columns]

# %%
df
# Out:
#        gender       age  hypertension  heart_disease ever_married  \
# id
# 9046     Male  1.051242             0              1          Yes
# 51676  Female  0.785889             0              0          Yes
# 31112    Male  1.626174             0              1          Yes
# 60182  Female  0.255182             0              0          Yes
# 1665   Female  1.581949             1              0          Yes
# ...       ...       ...           ...            ...          ...
# 18234  Female  1.626174             1              0          Yes
# 44873  Female  1.670400             0              0          Yes
# 19723  Female -0.363976             0              0          Yes
# 37544    Male  0.343633             0              0          Yes
# 44679  Female  0.034054             0              0          Yes
#
#            work_type Residence_type  avg_glucose_level       bmi  \
# id
# 9046         Private          Urban           2.706450  1.004893
# 51676  Self-employed          Rural           2.121652 -0.099142
# 31112        Private          Rural          -0.004867  0.472358
# 60182        Private          Urban           1.437473  0.719142
# 1665   Self-employed          Rural           1.501297 -0.631677
# ...              ...            ...                ...       ...
# 18234        Private          Urban          -0.494481 -0.099142
# 44873  Self-employed          Urban           0.420922  1.446507
# 19723  Self-employed          Rural          -0.511266  0.225574
# 37544        Private          Rural           1.328375 -0.423859
# 44679       Govt_job          Urban          -0.460692 -0.345927
#
#         smoking_status  stroke
# id
# 9046   formerly smoked       1
# 51676     never smoked       1
# 31112     never smoked       1
# 60182           smokes       1
# 1665      never smoked       1
# ...                ...     ...
# 18234     never smoked       0
# 44873     never smoked       0
# 19723     never smoked       0
# 37544  formerly smoked       0
# 44679          Unknown       0
#
# [5109 rows x 11 columns]

# %%
X
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
# ...       ...   ...           ...            ...          ...            ...
# 18234  Female  80.0             1              0          Yes        Private
# 44873  Female  81.0             0              0          Yes  Self-employed
# 19723  Female  35.0             0              0          Yes  Self-employed
# 37544    Male  51.0             0              0          Yes        Private
# 44679  Female  44.0             0              0          Yes       Govt_job
#
#       Residence_type  avg_glucose_level   bmi   smoking_status
# id
# 9046           Urban             228.69  36.6  formerly smoked
# 51676          Rural             202.21  28.1     never smoked
# 31112          Rural             105.92  32.5     never smoked
# 60182          Urban             171.23  34.4           smokes
# 1665           Rural             174.12  24.0     never smoked
# ...              ...                ...   ...              ...
# 18234          Urban              83.75  28.1     never smoked
# 44873          Urban             125.20  40.0     never smoked
# 19723          Rural              82.99  30.6     never smoked
# 37544          Rural             166.29  25.6  formerly smoked
# 44679          Urban              85.28  26.2          Unknown
#
# [5109 rows x 10 columns]

# %% [markdown]
# Encoding was done for categorical columns

# %%
X=pd.get_dummies(X)

# %% [markdown]
# test and train samples are spliited

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

# %%
X_train
# Out:
#         age  hypertension  heart_disease  avg_glucose_level   bmi  \
# id
# 45163  47.0             0              0              99.36  23.8
# 22330  45.0             0              0              82.94  29.3
# 43016  10.0             0              0              70.70  25.4
# 40980  79.0             1              0              72.04  23.6
# 1183   39.0             0              0              84.18  28.1
# ...     ...           ...            ...                ...   ...
# 67217  45.0             0              0              92.86  35.1
# 34376  16.0             0              0             113.47  19.5
# 10752  61.0             0              0              78.65  36.2
# 56939  55.0             0              0              92.98  25.6
# 43496  46.0             0              0              55.84  27.8
#
#        gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# id
# 45163              1            0                0                 1
# 22330              1            0                0                 1
# 43016              0            1                1                 0
# 40980              0            1                0                 1
# 1183               0            1                0                 1
# ...              ...          ...              ...               ...
# 67217              1            0                0                 1
# 34376              1            0                1                 0
# 10752              1            0                0                 1
# 56939              1            0                0                 1
# 43496              1            0                0                 1
#
#        work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# id
# 45163                   0                       0                  1
# 22330                   0                       0                  0
# 43016                   0                       0                  0
# 40980                   0                       0                  0
# 1183                    0                       0                  1
# ...                   ...                     ...                ...
# 67217                   0                       0                  1
# 34376                   0                       0                  0
# 10752                   0                       0                  1
# 56939                   0                       0                  0
# 43496                   1                       0                  0
#
#        work_type_Self-employed  work_type_children  Residence_type_Rural  \
# id
# 45163                        0                   0                     0
# 22330                        1                   0                     0
# 43016                        0                   1                     0
# 40980                        1                   0                     0
# 1183                         0                   0                     1
# ...                        ...                 ...                   ...
# 67217                        0                   0                     0
# 34376                        0                   1                     1
# 10752                        0                   0                     1
# 56939                        1                   0                     1
# 43496                        0                   0                     0
#
#        Residence_type_Urban  smoking_status_Unknown  \
# id
# 45163                     1                       0
# 22330                     1                       1
# 43016                     1                       1
# 40980                     1                       0
# 1183                      0                       0
# ...                     ...                     ...
# 67217                     1                       0
# 34376                     0                       1
# 10752                     0                       0
# 56939                     0                       0
# 43496                     1                       0
#
#        smoking_status_formerly smoked  smoking_status_never smoked  \
# id
# 45163                               0                            0
# 22330                               0                            0
# 43016                               0                            0
# 40980                               1                            0
# 1183                                0                            0
# ...                               ...                          ...
# 67217                               1                            0
# 34376                               0                            0
# 10752                               1                            0
# 56939                               0                            1
# 43496                               0                            1
#
#        smoking_status_smokes
# id
# 45163                      1
# 22330                      0
# 43016                      0
# 40980                      0
# 1183                       1
# ...                      ...
# 67217                      0
# 34376                      0
# 10752                      0
# 56939                      0
# 43496                      0
#
# [3576 rows x 20 columns]

# %%
X_train
# Out:
#         age  hypertension  heart_disease  avg_glucose_level   bmi  \
# id
# 45163  47.0             0              0              99.36  23.8
# 22330  45.0             0              0              82.94  29.3
# 43016  10.0             0              0              70.70  25.4
# 40980  79.0             1              0              72.04  23.6
# 1183   39.0             0              0              84.18  28.1
# ...     ...           ...            ...                ...   ...
# 67217  45.0             0              0              92.86  35.1
# 34376  16.0             0              0             113.47  19.5
# 10752  61.0             0              0              78.65  36.2
# 56939  55.0             0              0              92.98  25.6
# 43496  46.0             0              0              55.84  27.8
#
#        gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# id
# 45163              1            0                0                 1
# 22330              1            0                0                 1
# 43016              0            1                1                 0
# 40980              0            1                0                 1
# 1183               0            1                0                 1
# ...              ...          ...              ...               ...
# 67217              1            0                0                 1
# 34376              1            0                1                 0
# 10752              1            0                0                 1
# 56939              1            0                0                 1
# 43496              1            0                0                 1
#
#        work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# id
# 45163                   0                       0                  1
# 22330                   0                       0                  0
# 43016                   0                       0                  0
# 40980                   0                       0                  0
# 1183                    0                       0                  1
# ...                   ...                     ...                ...
# 67217                   0                       0                  1
# 34376                   0                       0                  0
# 10752                   0                       0                  1
# 56939                   0                       0                  0
# 43496                   1                       0                  0
#
#        work_type_Self-employed  work_type_children  Residence_type_Rural  \
# id
# 45163                        0                   0                     0
# 22330                        1                   0                     0
# 43016                        0                   1                     0
# 40980                        1                   0                     0
# 1183                         0                   0                     1
# ...                        ...                 ...                   ...
# 67217                        0                   0                     0
# 34376                        0                   1                     1
# 10752                        0                   0                     1
# 56939                        1                   0                     1
# 43496                        0                   0                     0
#
#        Residence_type_Urban  smoking_status_Unknown  \
# id
# 45163                     1                       0
# 22330                     1                       1
# 43016                     1                       1
# 40980                     1                       0
# 1183                      0                       0
# ...                     ...                     ...
# 67217                     1                       0
# 34376                     0                       1
# 10752                     0                       0
# 56939                     0                       0
# 43496                     1                       0
#
#        smoking_status_formerly smoked  smoking_status_never smoked  \
# id
# 45163                               0                            0
# 22330                               0                            0
# 43016                               0                            0
# 40980                               1                            0
# 1183                                0                            0
# ...                               ...                          ...
# 67217                               1                            0
# 34376                               0                            0
# 10752                               1                            0
# 56939                               0                            1
# 43496                               0                            1
#
#        smoking_status_smokes
# id
# 45163                      1
# 22330                      0
# 43016                      0
# 40980                      0
# 1183                       1
# ...                      ...
# 67217                      0
# 34376                      0
# 10752                      0
# 56939                      0
# 43496                      0
#
# [3576 rows x 20 columns]

# %% [markdown]
# Logistic Regssion algorithm was applied and predicted the values

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
ypred=LR.predict(X_test)

# %% [markdown]
# Accuracy sscore and classification report are calculated.

# %%
print(accuracy_score(y_test,ypred))
# Out:
# 0.9523809523809523

# %%
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98      1458
#            1       1.00      0.03      0.05        75
#
#     accuracy                           0.95      1533
#    macro avg       0.98      0.51      0.51      1533
# weighted avg       0.95      0.95      0.93      1533

# %% [markdown]
# Confusion Matrix and ROC curve was plotted also, Area under the curve was calculated for ROC curve.

# %%
cf_mat=confusion_matrix(y_test,ypred)

# %%
cmn = cf_mat.astype('float') / cf_mat.sum(axis=1)[:, np.newaxis]
_=sns.heatmap(cmn,annot=True,cmap='Blues')
_.set_title('Confusion Matrix Normalized')
_.set_xlabel('Predicted Values')
_.set_ylabel('Actual Vlaues')
_.xaxis.set_ticklabels(['False','True'])
_.yaxis.set_ticklabels(['False','True'])
plt.show()

# %%
y_scores_LR=LR.predict_proba(X_test)[:,1]
f_lr,t_lr,_=roc_curve(y_test,y_scores_LR)
roc_auc_LR=auc(f_lr,t_lr)
round(roc_auc_LR,2)
# Out:
# 0.84

# %%
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(f_lr, t_lr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('..\Capstone-2-Data-wranglling\healthcare-dataset-stroke-data.csv',index_col='id')

# %%
df=df[df['gender']!='Other']
df[df['gender']=='Other']
# Out:
# Empty DataFrame
# Columns: [gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df['bmi']=df['bmi'].fillna(df['bmi'].mean())

# %%
df.head()
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# id
# 9046     Male  67.0             0              1          Yes        Private
# 51676  Female  61.0             0              0          Yes  Self-employed
# 31112    Male  80.0             0              1          Yes        Private
# 60182  Female  49.0             0              0          Yes        Private
# 1665   Female  79.0             1              0          Yes  Self-employed
#
#       Residence_type  avg_glucose_level       bmi   smoking_status  stroke
# id
# 9046           Urban             228.69  36.60000  formerly smoked       1
# 51676          Rural             202.21  28.89456     never smoked       1
# 31112          Rural             105.92  32.50000     never smoked       1
# 60182          Urban             171.23  34.40000           smokes       1
# 1665           Rural             174.12  24.00000     never smoked       1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
features=['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status']

# %%
X=df[features]
y=df.stroke

# %%
X=pd.get_dummies(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train
# Out:
#          age  hypertension  heart_disease  avg_glucose_level   bmi  \
# id
# 7233   15.00             0              0              74.83  17.4
# 56179  29.00             0              0             207.58  22.8
# 36388  44.00             1              0              91.28  26.5
# 59405  68.00             1              0             150.74  40.3
# 46643  62.00             0              0              82.57  36.0
# ...      ...           ...            ...                ...   ...
# 61667  61.00             0              0             144.14  29.8
# 1307   61.00             1              0             170.05  60.2
# 31481   1.16             0              0              97.28  17.8
# 31454  38.00             0              0              93.93  21.5
# 28933  46.00             0              0             100.15  50.3
#
#        gender_Female  gender_Male  ever_married_No  ever_married_Yes  \
# id
# 7233               0            1                1                 0
# 56179              0            1                1                 0
# 36388              0            1                0                 1
# 59405              1            0                0                 1
# 46643              1            0                0                 1
# ...              ...          ...              ...               ...
# 61667              1            0                0                 1
# 1307               1            0                0                 1
# 31481              1            0                1                 0
# 31454              1            0                0                 1
# 28933              1            0                0                 1
#
#        work_type_Govt_job  work_type_Never_worked  work_type_Private  \
# id
# 7233                    0                       0                  0
# 56179                   0                       0                  1
# 36388                   0                       0                  1
# 59405                   0                       0                  1
# 46643                   0                       0                  1
# ...                   ...                     ...                ...
# 61667                   0                       0                  1
# 1307                    0                       0                  1
# 31481                   0                       0                  0
# 31454                   1                       0                  0
# 28933                   0                       0                  1
#
#        work_type_Self-employed  work_type_children  Residence_type_Rural  \
# id
# 7233                         0                   1                     1
# 56179                        0                   0                     0
# 36388                        0                   0                     1
# 59405                        0                   0                     0
# 46643                        0                   0                     1
# ...                        ...                 ...                   ...
# 61667                        0                   0                     1
# 1307                         0                   0                     1
# 31481                        0                   1                     0
# 31454                        0                   0                     1
# 28933                        0                   0                     1
#
#        Residence_type_Urban  smoking_status_Unknown  \
# id
# 7233                      0                       1
# 56179                     1                       0
# 36388                     0                       0
# 59405                     1                       1
# 46643                     0                       0
# ...                     ...                     ...
# 61667                     0                       0
# 1307                      0                       0
# 31481                     1                       1
# 31454                     0                       0
# 28933                     0                       0
#
#        smoking_status_formerly smoked  smoking_status_never smoked  \
# id
# 7233                                0                            0
# 56179                               0                            0
# 36388                               0                            1
# 59405                               0                            0
# 46643                               1                            0
# ...                               ...                          ...
# 61667                               0                            1
# 1307                                0                            0
# 31481                               0                            0
# 31454                               0                            1
# 28933                               0                            0
#
#        smoking_status_smokes
# id
# 7233                       0
# 56179                      1
# 36388                      0
# 59405                      0
# 46643                      0
# ...                      ...
# 61667                      0
# 1307                       1
# 31481                      0
# 31454                      0
# 28933                      1
#
# [3576 rows x 20 columns]

# %%
stdscaler=StandardScaler()
X_train=stdscaler.fit_transform(X_train)
X_test=stdscaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[-1.24098632, -0.31617913, -0.23556308, ..., -0.46466435,
#         -0.76308642, -0.42678889],
#        [-0.62269788, -0.31617913, -0.23556308, ..., -0.46466435,
#         -0.76308642,  2.34307878],
#        [ 0.03975403,  3.16276413, -0.23556308, ..., -0.46466435,
#          1.31046756, -0.42678889],
#        ...,
#        [-1.85220862, -0.31617913, -0.23556308, ..., -0.46466435,
#         -0.76308642, -0.42678889],
#        [-0.22522673, -0.31617913, -0.23556308, ..., -0.46466435,
#          1.31046756, -0.42678889],
#        [ 0.12808095, -0.31617913, -0.23556308, ..., -0.46466435,
#         -0.76308642,  2.34307878]])

# %%
LR=LogisticRegression()
LR.fit(X_train,y_train)
ypred=LR.predict(X_test)

# %%
print(accuracy_score(y_test,ypred))
# Out:
# 0.9425962165688193
